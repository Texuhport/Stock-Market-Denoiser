# %%
#Guarantee Directory
# %cd C:\\Users\\Oluwa\\GITHUB\\Bootcamp\\ASSIGNMENTS\\Project_Uno
# Out:
# C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Project_Uno

# %%
# initial imports
import pandas as pd
import hvplot.pandas
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

import os
import requests

import yfinance as yf
import pytz
import sys
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
#Variable Import
#Short-Term Variables

#The 7, 21, and 40-day rolling averages of the volume change for each ticker
# %store -r vol_7days
# %store -r vol_21days
# %store -r vol_40days
#MacD Calculation
# %store -r MACD_world_stock_df
#RSI Calculation
# %store -r RSI_world_stock_df
#MovingAverage Calculation
# %store -r ma_world_stock_df
#Daily Return
# %store -r daily_return
#world_stock_data_clean
# %store -r world_stock_df

#Long-Term Variables
#Cumulative Returns Dataframe
# %store -r c_results_df
#Annualized Returns Dataframe
# %store -r  a_results_df
#Total Volume comparison Dataframe
# %store -r  v_results_df
#Combined Sharpe Ratios
# %store -r  sharpe_ratios_combined
#Best SMA Results
# %store -r  sma_summary_df

# %%
#USER INPUT

#INVESTMENT GOALS
print("Would you prefer to analyze based on current or historical data?")
print("If you input 'current' we'll run a short-term analysis on the stocks on the market")
print("If you input 'history' we'll run a long-term analysis on the stocks on the market")

print("")

inv_goal= input("Enter your preferred investment term")

print("")
print("")
# Out:
# Would you prefer to analyze based on current or historical data?
# If you input 'current' we'll run a short-term analysis on the stocks on the market
# If you input 'history' we'll run a long-term analysis on the stocks on the market
# Enter your preferred investment term history

# %%
#### Define functions to run Jupyter Notebook cells
def RunShort():
    # %run -i long_term.ipynb

def RunLong():
    # %run -i Short_term_analysis.ipynb

# Check the value of inv_goal and run the appropriate notebook
if inv_goal == "current":
    RunShort()
elif inv_goal == "history":
    RunLong()
else:
    print("Sorry that's not a valid investment goal, input 'current' or 'history'")
# Out:
# Your choice of 'Trade Term' will define the timeframe with which we will analyze stock returns
# Select a trade term that matches your current investment goals for collecting returns from stock investments
#
# Choose a Trade Term From These Options:
# 1. 1Yrs (1 Year)
# 2. 5Yrs (5 Years)
# 3. 10Yrs (10 Years)
# 4. 15Yrs (15 Years)
# 5. 7Dys (7 Days)
# 6. 21Dys (21 Days)
# 7. 40Dys (40 Days)
# Enter your trade term 10Yrs
# Your choice of 'Risk Threshold' will define how risky and volatile the stocks in the final portfolio will be
# Select a risk threshold that matches your comfort levels when it comes to risk
#
# Choose a Risk Threshold:
# 1. high
# 2. mid
# 3. low
# Enter your risk threshold low
# Stored 'vol_7days' (Series)
# Stored 'vol_21days' (Series)
# Stored 'vol_40days' (Series)
# Stored 'MACD_world_stock_df' (DataFrame)
# Stored 'RSI_world_stock_df' (DataFrame)
# Stored 'ma_world_stock_df' (DataFrame)
# Stored 'daily_return' (DataFrame)
# Stored 'world_stock_df' (DataFrame)

# %%
# Out:
#      Ticker     SMA_1260     SMA_2520     SMA_3780
# 1   S&P 500  3666.196245  2936.420428  2367.846642
# 9       MMM   143.145503   138.396439   111.299215
# 2       DIS   129.320338   110.919983    85.249045
# 3      TSLA   156.435700    86.497212          NaN
# 4      NVDA   150.979395    85.645778    58.133555
# 6      CROX    69.421301    40.675032    31.398667
# 7       AMD    72.152381    39.491020    28.189087
# 10      JWN    26.889125    35.981680    33.408286
# 0      PTON          NaN          NaN          NaN
# 5      PINS          NaN          NaN          NaN
# 8        ZI          NaN          NaN          NaN
